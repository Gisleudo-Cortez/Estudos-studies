# %%
# run this to shorten the data import from the files
path_data = '/home/nero/Documents/Estudos/DataCamp/Python/Introduction_to_Natural_Language_Processing_in_Python/datasets/'
import pandas as pd
from nltk.tokenize import word_tokenize, regexp_tokenize, sent_tokenize
import nltk

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /home/nero/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/nero/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/nero/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/nero/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# single sample
with open(path_data + 'News articles/articles.txt') as file:
    article = file.read()
    file.close()

# %%
# exercise 01

"""
NER with NLTK

You're now going to have some fun with named-entity recognition! A scraped news article has been pre-loaded into your workspace. Your task is to use nltk to find the named entities in this article.

What might the article be about, given the names you found?

Along with nltk, sent_tokenize and word_tokenize from nltk.tokenize have been pre-imported.
"""

# Instructions

"""

    Tokenize article into sentences.
    Tokenize each sentence in sentences into words using a list comprehension.
    Inside a list comprehension, tag each tokenized sentence into parts of speech using nltk.pos_tag().
    Chunk each tagged sentence into named-entity chunks using nltk.ne_chunk_sents(). Along with pos_sentences, specify the additional keyword argument binary=True.
    Loop over each sentence and each chunk, and test whether it is a named-entity chunk by testing if it has the attribute label, and if the chunk.label() is equal to "NE". If so, print that chunk.

"""

# solution

# Tokenize the article into sentences: sentences
sentences = sent_tokenize(article)

# Tokenize each sentence into words: token_sentences
token_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences] 

# Create the named entity chunks: chunked_sentences
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary = True)

# Test for stems of the tree with 'NE' tags
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, "label") and chunk.label() == "NE":
            print(chunk)


#----------------------------------#

# Conclusion

"""
Great work!
"""
# Out:
# (NE EPA/NNP Image/NNP)
# (NE US/JJ)
# (NE Reuters/NNPS)
# (NE Portland/NNP)
# (NE Oregon/NNP)
# (NE Greyball/NNP)
# (NE Portland/NNP)
# (NE Uber/NNP)
# (NE Uber/NNP)
# (NE New/NNP York/NNP Times/NNP)
# (NE Uber/NNP)
# (NE Alexa/NNP)
# (NE Siri/NNP)
# (NE Rachael/NNP Tatman/NNP)
# (NE South/NNP)
# (NE New/NNP Zealand/NNP)
# (NE Tatman/NNP)
# (NE San/NNP Francisco/NNP)
# (NE University/NNP)
# (NE Washington/NNP)
# (NE Virtual/NNP Assistant/NNP Summit/NNP)
# (NE Park/NNP Central/NNP Hotel/NNP)
# (NE Apple/NNP)
# (NE Siri/NNP)
# (NE Amazon/NNP)
# (NE Echo/NNP)
# (NE Tatman/NNP)
# (NE Tatman/NNP)
# (NE YouTube/NNP)
# (NE Southern/JJ)
# (NE California/NNP)
# (NE South/NNP)
# (NE United/NNP States/NNPS)
# (NE Southern/NNP)
# (NE Stephen/NNP Scarr/NNP)
# (NE CEO/NNP)
# (NE eContext/NN)
# (NE YouTube/NNP)
# (NE Amazon/NNP)
# (NE Alexa/NNP)
# (NE Alonso/NNP Martinez/NNP)
# (NE Pixar/NNP Animation/NNP Studios/NNP)
# (NE Martinez/NNP)
# (NE Emeryville/NNP)
# (NE Elena/NNP Corina/NNP Grigore/NNP)
# (NE Yale/NNP University/NNP)
# (NE Social/NNP Robotics/NNP Lab/NNP)
# (NE Grigore/NNP)
# (NE Ikea/NNP)
# (NE Grigore/NNP)
# (NE San/NNP Francisco/NNP Chronicle/NNP)
# (NE Email/NN)
# (NE French/JJ)
# (NE Britain/NNP)
# (NE Germany/NNP)
# (NE Computer/NNP)
# (NE Advertisement/NNP)
# (NE Europe/NNP)
# (NE United/NNP States/NNPS)
# (NE Facebook/NNP)
# (NE Algorithms/NNP)
# (NE Claire/NNP Wardle/NNP)
# (NE First/NNP Draft/NNP News/NNP)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE American/JJ)
# (NE Advertisement/NNP)
# (NE European/JJ)
# (NE United/NNP States/NNPS)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE Advertisement/NNP)
# (NE Europeans/NNPS)
# (NE Sputnik/NNP)
# (NE Russian/JJ)
# (NE Advertisement/NNP)
# (NE Europe/NNP)
# (NE Janis/NNP Sarts/NNP)
# (NE NATO/NNP Strategic/NNP Communications/NNP Center/NNP)
# (NE Excellence/NNP)
# (NE Riga/NNP)
# (NE Latvia/NNP)
# (NE American/JJ)
# (NE Facebook/NNP)
# (NE Google/NNP)
# (NE Silicon/NNP Valley/NNP)
# (NE Invalid/NNP)
# (NE Sign/NNP Up/NNP)
# (NE New/NNP York/NNP Times/NNP)
# (NE Please/NNP)
# (NE New/NNP York/NNP Times/NNP)
# (NE United/NNP States/NNPS)
# (NE Facebook/NNP)
# (NE Dutch/JJ)
# (NE March/NNP)
# (NE French/JJ)
# (NE France/NNP)
# (NE Photo/NNP)
# (NE Facebook/NNP)
# (NE German/JJ)
# (NE Advertisement/NNP)
# (NE Google/NNP)
# (NE European/JJ)
# (NE British/JJ)
# (NE Advertisement/NNP)
# (NE French/JJ)
# (NE David/NNP Dieudonné/NNP)
# (NE France/NNP)
# (NE Saudi/NNP Arabia/NNP)
# (NE Emmanuel/NNP Macron/NNP)
# (NE Advertisement/NNP)
# (NE Silicon/NNP Valley/NNP)
# (NE David/NNP Chavalarias/NNP)
# (NE French/JJ)
# (NE French/JJ)
# (NE Advertisement/NNP)
# (NE United/NNP States/NNPS)
# (NE Dean/NNP Pomerleau/NNP)
# (NE Carnegie/NNP Mellon/NNP University/NNP)
# (NE Pittsburgh/NNP)
# (NE Advertisement/NNP)
# (NE Delip/NNP Rao/NNP)
# (NE Google/NNP)
# (NE Mr./NNP Pomerleau/NNP)
# (NE Fake/NNP News/NNP Challenge/NNP)
# (NE Mr./NNP Pomerleau/NNP)
# (NE Advertisement/NNP)
# (NE Mr./NNP Pomerleau/NNP)
# (NE Jimmy/NNP Wales/NNP)
# (NE Wikipedia/NNP)
# (NE Part/NN)
# (NE United/NNP States/NNPS)
# (NE Mr./NNP Wales/NNP)
# (NE Advertisement/NNP)
# (NE Morgan/NNP Stanley/NNP)
# (NE Rise/NNP)
# (NE Chilli/NNP Padi/NNP Nonya/NNP Cafe/NNP)
# (NE Singapore/NNP)
# (NE United/NNP Nations/NNP)
# (NE U.N./NNP)
# (NE Chile/NNP)
# (NE China/NNP)
# (NE United/NNP States/NNPS)
# (NE Germany/NNP)
# (NE Japan/NNP)
# (NE South/NNP Korea/NNP)
# (NE China/NNP)
# (NE China/NNP)
# (NE Evercore/NNP ISI/NNP)
# (NE United/NNP States/NNPS)
# (NE France/NNP)
# (NE China/NNP)
# (NE Nobel/NNP)
# (NE Daniel/NNP Kahneman/NNP)
# (NE China/NNP)
# (NE Concern/NN)
# (NE Oxford/NNP University/NNP)
# (NE Carl/NNP Benedikt/NNP Frey/NNP)
# (NE Michael/NNP Osborne/NNP)
# (NE U.S./NNP)
# (NE Machine/NNP Intelligence/NNP Research/NNP Institute/NNP)
# (NE University/NNP)
# (NE California/NNP)
# (NE Berkeley/NNP)
# (NE American/JJ)
# (NE Martin/NNP Ford/NNP)
# (NE Robots/NNP)
# (NE Seven/NNP)
# (NE Japanese/JJ)
# (NE Germany/NNP)
# (NE Japan/NNP)
# (NE South/NNP Korea/NNP)
# (NE True/NN)
# (NE China/NNP)
# (NE Saudi/NNP Arabia/NNP)
# (NE Singapore/NNP)
# (NE Chile/NNP)
# (NE Australia/NNP)
# (NE Japan/NNP)
# (NE Germany/NNP)
# (NE Germany/NNP)
# (NE Germany/NNP)
# (NE Japan/NNP)
# (NE Worldwide/NNP)
# (NE United/NNP States/NNPS)
# (NE International/NNP Federation/NNP)
# (NE Robotics/NNP)
# (NE South/NNP Korea/NNP)
# (NE Japan/NNP)
# (NE Germany/NNP)
# (NE United/NNP States/NNPS)
# (NE China/NNP)
# (NE Chinese/JJ)
# (NE ECM/NNP)
# (NE Prof/NNP Björn/NNP Schuller/NNP)
# (NE Imperial/NNP College/NNP London/NNP)
# (NE Schuller/NNP)
# (NE Minlie/NNP Huang/NNP)
# (NE Tsinghua/NNP University/NNP)
# (NE Beijing/NNP)
# (NE Chinese/JJ)
# (NE Huang/NNP)
# (NE Eugene/NNP Goostman/NNP)
# (NE Ukrainian/JJ)
# (NE English/NNP)
# (NE Microsoft/NNP)
# (NE Tay/NNP)
# (NE Twitter/NNP)
# (NE Sandra/NNP Wachter/NNP)
# (NE Oxford/NNP Internet/NNP Institute/NNP)
# (NE Wachter/NNP)
# (NE Schuller/NNP)
# '\nGreat work!\n'

# %%
file_paths = ['articles.txt', 'blaise.txt', 'french.txt', 'uber_apple.txt']  # List of file paths

file_contents = []  # List to store the contents of each file

for file_path in file_paths:
    with open(path_data + 'News articles/' + file_path, 'r') as file:
        content = file.read()
        file_contents.append(content)

article = '\n'.join(file_contents)  # Combine the contents using a newline separator

# %%
import nltk
import matplotlib.pyplot as plt

# Sample sentences
sentences = sent_tokenize(article)

# Tokenize the sentences
tokenized_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# Perform part-of-speech tagging
pos_tagged_sentences = [nltk.pos_tag(tokens) for tokens in tokenized_sentences]

# Perform named entity chunking
ne_chunked_sentences = nltk.ne_chunk_sents(pos_tagged_sentences, binary=False)

# Count named entity types
ne_type_counts = {}
for sentence in ne_chunked_sentences:
    for chunk in sentence:
        if hasattr(chunk, 'label'):
            ne_type = chunk.label()
            ne_type_counts[ne_type] = ne_type_counts.get(ne_type, 0) + 1

# Plot the named entity types
labels = ne_type_counts.keys()
values = ne_type_counts.values()

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)

# Display the chart
plt.show()

# %%
# Tokenize the article into sentences: sentences
sentences = sent_tokenize(article)

# Tokenize each sentence into words: token_sentences
token_sentences = [nltk.word_tokenize(sent) for sent in sentences]

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences] 

# Create the named entity chunks: chunked_sentences
chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary = True)

# %%
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
# exercise 02

"""
Charting practice

In this exercise, you'll use some extracted named entities and their groupings from a series of newspaper articles to chart the diversity of named entity types in the articles.

You'll use a defaultdict called ner_categories, with keys representing every named entity group type, and values to count the number of each different named entity type. You have a chunked sentence list called chunked_sentences similar to the last exercise, but this time with non-binary category names.

You can use hasattr() to determine if each chunk has a 'label' and then simply use the chunk's .label() method as the dictionary key.
"""

# Instructions

"""

    Create a defaultdict called ner_categories, with the default type set to int.
---

    Fill up the dictionary with values for each of the keys. Remember, the keys will represent the label().
        In the outer for loop, iterate over chunked_sentences, using sent as your iterator variable.
        In the inner for loop, iterate over sent. If the condition is true, increment the value of each key by 1.
        Remember to use the chunk's .label() method as the key!
    For the pie chart labels, create a list called labels from the keys of ner_categories, which can be accessed using .keys().
---

    Use a list comprehension to create a list called values, using the .get() method on ner_categories to compute the values of each label v.
    Use plt.pie() to create a pie chart for each of the NER categories. Along with values and labels=labels, pass the extra keyword arguments autopct='%1.1f%%' and startangle=140 to add percentages to the chart and rotate the initial start angle.
        This step has been done for you.
    Display your pie chart. Was the distribution what you expected?

"""

# solution

# Create the defaultdict: ner_categories
ner_categories = defaultdict(int)

# Create the nested for loop
for sent in nltk.ne_chunk_sents(pos_sentences, binary = True):
    for chunk in sent:
        if hasattr(chunk, 'label'):
            ner_categories[chunk.label()] += 1
            
# Create a list from the dictionary keys for the chart labels: labels
labels = list(ner_categories.keys())

# Create a list of the values: values
values = [ner_categories.get(v) for v in labels]

# Create the pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)

# Display the chart
plt.show()

#----------------------------------#

# Conclusion

"""
Well done!
"""
# Out:
# '\nWell done!\n'

# %%
# exercise 03

"""
Comparing NLTK with spaCy NER

Using the same text you used in the first exercise of this chapter, you'll now see the results using spaCy's NER annotator. How will they compare?

The article has been pre-loaded as article. To minimize execution times, you'll be asked to specify the keyword argument disable=['tagger', 'parser', 'matcher'] when loading the spaCy model, because you only care about the entity in this exercise.
"""

# Instructions

"""

    Import spacy.
    Load the 'en_core_web_sm' model using spacy.load(). Specify the additional keyword arguments disable=['tagger', 'parser', 'matcher'].
    Create a spacy document object by passing article into nlp().
    Using ent as your iterator variable, iterate over the entities of doc and print out the labels (ent.label_) and text (ent.text).

"""

# solution

# Import spacy
import spacy

# Instantiate the English model: nlp
nlp = spacy.load('en_core_web_sm', disable = ['tagger','parser','matcher'])

# Create a new document: doc
doc = nlp(article)

# Print all of the found entities and their labels
for ent in doc.ents:
    print(ent.label_, ent.text)


#----------------------------------#

# Conclusion

"""
Great work!
"""
# Out:
# /home/nero/Documents/Estudos/estudos/lib/python3.11/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# ORG EPA
# ORG Uber
# PERSON Uber
# GPE US
# ORG Uber
# ORG Reuters
# GPE Portland
# GPE Oregon
# DATE last week
# GPE Portland
# PERSON Uber
# DATE April 2015
# PERSON Uber
# ORG the New York Times
# DATE earlier this year
# PERSON Uber
# ORG Google
# PRODUCT Waymo
# ORG Alexa
# PERSON Siri
# PERSON Rachael Tatman
# LOC South
# GPE New Zealand
# PERSON Tatman
# DATE last week
# GPE San Francisco
# PRODUCT Twitter
# PERSON Tatman
# ORG the University of Washington’s
# DATE two-day
# DATE Friday
# FAC the Park Central Hotel
# WORK_OF_ART Deep Learning Summit
# CARDINAL about 600
# ORG Apple
# ORG Amazon
# CARDINAL two
# PERSON Tatman
# PERSON Tatman
# ORG YouTube
# NORP Southern
# GPE California
# LOC South
# GPE the United States
# NORP Southern
# PERSON Stephen Scarr
# ORG Info.com
# ORG eContext
# PERCENT 20 percent
# CARDINAL 1
# PERSON Scarr
# ORG YouTube
# ORG Amazon
# ORG Alexa
# PERSON Alonso Martinez
# ORG Pixar Animation Studios
# PERSON Martinez
# WORK_OF_ART Inside Out
# CARDINAL two
# PERSON Emeryville
# PERSON Elena Corina Grigore
# ORG Yale University’s
# ORG Social Robotics Lab
# PERSON Grigore
# GPE Ikea
# PERSON Grigore
# PERSON Benny Evangelista
# GPE San Francisco Chronicle
# PERSON Twitter
# CARDINAL @ChronicleBenny
# NORP French
# ORDINAL second
# DATE May 7
# GPE Britain
# GPE Germany
# DATE the coming months
# PERSON Advertisement Continue
# LOC Europe
# GPE the United States
# DATE November
# PRODUCT Twitter
# PERSON Claire Wardle
# ORG First Draft News
# GPE the United States
# LOC Europe
# GPE the United States
# LOC Europe
# NORP American
# PERSON Advertisement Continue
# NORP European
# GPE the United States
# GPE the United States
# LOC Europe
# PERSON Advertisement Continue
# NORP Europeans
# PERSON Sputnik
# NORP Russian
# PERSON Advertisement Continue
# LOC Europe
# PERSON Janis Sarts
# ORG the NATO Strategic Communications Center of Excellence
# GPE Riga
# GPE Latvia
# DATE May
# NORP American
# NORP Facebook
# ORG Google
# DATE daily
# LOC Silicon Valley
# ORG Invalid
# ORG The New York Times's
# ORG New York Times
# GPE the United States
# NORP Dutch
# DATE March
# ORDINAL first
# NORP French
# DATE April 23
# CARDINAL 30,000
# GPE France
# NORP German
# NORP German
# PERSON Advertisement Continue
# DATE last year
# ORG Google
# CARDINAL almost 20
# NORP European
# CARDINAL two
# NORP British
# DATE June 8
# PERSON Advertisement Continue
# NORP French
# PERSON David Dieudonné
# GPE France
# CARDINAL 43
# DATE February
# GPE Saudi Arabia
# PERSON Emmanuel Macron
# PERSON Advertisement Continue
# PERSON Dieudonné
# LOC Silicon Valley’s
# PERSON David Chavalarias
# NORP French
# MONEY more than 80 million
# NORP French
# PERSON Advertisement Continue
# GPE the United States
# DATE last year
# ORG Dean Pomerleau
# ORG Carnegie Mellon University
# GPE Pittsburgh
# PRODUCT Twitter
# PERSON Advertisement Continue
# PERSON Delip Rao
# ORG Google
# MONEY 2,000
# DATE early this year
# CARDINAL more than 100
# PERSON Pomerleau
# ORG Fake News Challenge
# PERCENT almost 90 percent
# PERSON Pomerleau
# DATE mid-90s
# DATE June
# PERSON Advertisement Continue
# PERSON Pomerleau
# PERSON Advertisement Continue
# PERSON Jimmy Wales
# ORG Wikipedia
# GPE Wikipedia
# PERSON Wikitribune
# GPE the United States
# PERSON Wales
# PERSON Advertisement Continue
# PERSON Ruchir Sharma
# ORG Morgan Stanley Investment Management
# FAC Chilli Padi Nonya Cafe
# GPE Singapore
# ORG REUTERS/Edgar Su
# ORG The United Nations
# MONEY 7.3 billion
# DATE 2050
# NORP neo-Malthusians
# CARDINAL one
# CARDINAL 2.5 billion
# DATE the 1960s
# CARDINAL almost half
# PERCENT just 1 percent
# ORG U.N.
# GPE Chile
# GPE China
# CARDINAL One
# PERCENT 1 percent
# PERCENT roughly 2 percent
# DATE the past decade
# GPE the United States
# CARDINAL almost half
# CARDINAL two-thirds
# PERCENT 0.5 percent
# DATE 2008
# GPE Germany
# GPE Japan
# GPE South Korea
# GPE China
# DATE last year
# ORDINAL first
# DATE the 1950s
# GPE China
# CARDINAL 1 million
# ORG ISI
# GPE the United States
# CARDINAL more than four
# GPE France
# GPE China
# WORK_OF_ART Nobel
# PERSON Daniel Kahneman
# GPE China
# GPE Beijing
# ORG Oxford University
# PERSON Carl Benedikt
# PERSON Michael Osborne
# DATE 2013
# CARDINAL nearly half
# GPE U.S.
# DATE the next decade
# CARDINAL two
# ORG The Machine Intelligence Research Institute
# ORG the University of California at Berkeley
# DATE today
# DATE about 20 years
# DATE 1955
# CARDINAL millions
# NORP American
# PERSON Martin Ford’s
# WORK_OF_ART The Rise of the Robots
# DATE 2008
# CARDINAL Seven
# DATE at least the 1970s
# NORP Japanese
# PERCENT 0.8 percent
# GPE Germany
# GPE Japan
# GPE South Korea
# GPE China
# PERCENT 2 percent
# DATE the 1980s
# CARDINAL 17
# CARDINAL 20
# CARDINAL only two
# GPE Nigeria
# GPE Saudi Arabia
# DATE the 1980s
# GPE Singapore
# GPE Chile
# GPE Australia
# GPE Japan
# GPE Germany
# GPE Germany
# CARDINAL roughly 1 million
# DATE 2015
# GPE Germany
# CARDINAL 1.5 million
# DATE each year
# DATE 2030
# GPE Japan
# CARDINAL fewer than 70,000
# CARDINAL 1 million
# DATE annually
# CARDINAL about 320 million
# CARDINAL just 1.6 million
# CARDINAL Nearly half
# GPE the United States
# ORDINAL fourth
# ORG the International Federation of Robotics
# GPE South Korea
# CARDINAL 531
# CARDINAL 10,000
# GPE Japan
# CARDINAL 305
# GPE Germany
# CARDINAL 301
# GPE The United States
# ORDINAL eighth
# CARDINAL 176
# GPE China
# CARDINAL only 49
# DATE Today
# NORP Chinese
# ORG ECM
# PERSON Prof Björn Schuller
# ORG Imperial College London
# DATE daily
# PERCENT 61%
# WORK_OF_ART Wizard of Oz
# ORG AI
# ORG Schuller
# PERSON Minlie Huang
# ORG Tsinghua University
# GPE Beijing
# ORDINAL first
# PERSON Huang
# CARDINAL 23,000
# NORP Chinese
# ORG Weibo
# CARDINAL millions
# CARDINAL five
# CARDINAL one
# PERSON Huang
# PERSON Eugene Goostman
# DATE 13-year
# NORP Ukrainian
# LANGUAGE English
# ORG Microsoft
# PERSON Tay
# NORP Twitter
# NORP Nazi
# TIME less than 24 hours
# PERSON Sandra Wachter
# ORG the Oxford Internet Institute
# DATE today
# CARDINAL One
# PERSON Wachter
# ORG Schuller
# DATE the year
# CARDINAL two
# ORG ChronoNet
# DATE 1951
# DATE 1971
# PERSON Ilya Kostrikov
# PERSON Tobias Weyand’s
# ORG ChronoNet
# ORG CNN
# DATE the year
# DATE the past century
# CARDINAL many millions
# CARDINAL One
# CARDINAL one
# PERSON Marco Polo
# MONEY millions, billions
# CARDINAL trillions
# DATE between the ages of 18 and 23
# ORG AI
# PERSON Wu
# PERSON Zhang
# CARDINAL one
# PERSON Xiaolin Wu
# PERSON Xi Zhang’s
# DATE November 2016
# PERSON Wu
# PERSON Zhang
# PERCENT nearly 90%
# CARDINAL 2
# DATE today
# ORG Lombroso
# ORG Lombroso
# CARDINAL 1
# NORP Italians
# NORP Italians
# PERSON Villella
# ORG Cesare Lombroso
# ORG Lombroso
# DATE 1844
# GPE Italy
# CARDINAL five
# CARDINAL two
# CARDINAL two
# PERSON Giuseppe Villella
# GPE Pavia
# GPE Italy
# DATE 1864
# GPE Stockholm
# DATE 1950
# PERSON Nixon
# DATE 1972
# GPE Atlanta
# CARDINAL millions
# CARDINAL 3
# ORG ChronoNet
# DATE years
# DATE the 20th century
# GPE Stockholm
# ORG AI
# DATE 2006
# DATE the year
# CARDINAL 4
# DATE the year
# ORG ChronoNet
# PERSON Wu
# PERSON Zhang
# ORDINAL first
# PERSON Wu
# PERSON Zhang
# CARDINAL 1,856
# CARDINAL 80x80
# NORP Chinese
# DATE between 18 and 55 years old
# CARDINAL 730
# ORG the ministry of public security
# GPE China
# GPE Guangdong
# GPE Jiangsu
# GPE Liaoning
# GPE China
# CARDINAL 730
# CARDINAL 235
# CARDINAL 536
# CARDINAL 1,126
# CARDINAL roughly half
# PERSON Wu
# PERSON Zhang
# CARDINAL one
# CARDINAL four
# CARDINAL One
# ORG AlexNet
# DATE 2012
# ORG Google
# PERSON Alex Krizhevsky
# ORG Ilya Sutskever
# PERSON Geoffrey Hinton
# ORG ChronoNet
# ORG CNN
# PERCENT nearly 90%
# PERCENT 75%
# ORDINAL first
# PERCENT 90%
# DATE 2015
# PERSON Gil Levi
# PERSON Tal Hassner
# ORG AlexNet
# CARDINAL 5
# PERCENT 86.8%
# CARDINAL 6
# PERSON Wu
# PERSON Zhang
# ORG CNN
# PERCENT just over 6%
# CARDINAL One
# CARDINAL fewer than 2000
# ORG CNN
# ORG AlexNet
# CARDINAL One
# DATE between 18 and 55
# CARDINAL three
# CARDINAL three
# CARDINAL only three
# ORG ChronoNet
# PERSON Wu
# PERSON Zhang
# CARDINAL two
# PERCENT 19.6%
# PERCENT 23.4%
# CARDINAL two
# PERCENT 5.6%
# CARDINAL 7
# CARDINAL 1
# CARDINAL 3
# PERSON Wu
# PERSON Zhang’s
# CARDINAL six
# CARDINAL six
# NORP Chinese
# NORP Western
# CARDINAL three
# CARDINAL one
# CARDINAL three
# CARDINAL six
# CARDINAL 8
# CARDINAL hundreds or thousands
# CARDINAL well under one tenth
# CARDINAL 9
# PERSON Wu
# PERSON Zhang
# CARDINAL 2011
# GPE al.
# ORG The Accuracy of Inferences About Criminality Based on Facial Appearance
# CARDINAL two
# PERSON Wu
# PERSON Zhang
# GPE Valla
# GPE al.’s
# PERSON Wu
# PERSON Zhang
# DATE 2014
# ORG Psychological Science
# ORG Inferring Character From Faces
# CARDINAL one
# DATE 4-year olds
# DATE the last decade
# ORG Valence
# CARDINAL one
# CARDINAL 4
# PERSON Wu
# PERSON Zhang
# CARDINAL 3
# PERSON Wu
# ORDINAL first
# CARDINAL two
# PERSON Wu
# PERSON Zhang
# ORG Cesare Lombroso
# CARDINAL 10
# PERSON Greeks
# CARDINAL 11
# ORG Renaissance
# GPE Porta
# ORG De humana physiognomonia
# CARDINAL 12
# CARDINAL 5
# NORP Giambattista
# GPE Porta
# ORG De humana physiognomonia
# GPE Naples
# DATE 1586
# DATE the 1700s
# NORP Swiss
# NORP Victorian
# PERSON Francis Galton
# CARDINAL 1822–1911
# ORG Lombroso
# CARDINAL 13
# CARDINAL one
# ORDINAL first
# CARDINAL one
# ORDINAL first
# CARDINAL 6
# PERSON Francis Galton
# CARDINAL 1850–1950
# ORG Lombroso
# GPE Italy
# DATE 19th century
# NORP American
# PERSON Samuel Morton
# PERSON Josiah Nott
# PERSON George Gliddon
# DATE 1854
# WORK_OF_ART Types of Mankind
# NORP Caucasian
# GPE Porta
# CARDINAL 6
# ORG Nott
# PERSON Gliddon
# WORK_OF_ART Types of Mankind
# DATE 1854
# TIME Later in the 19th century
# NORP Darwinian
# FAC Types of Mankind
# PERSON Morton
# ORG grey
# CARDINAL 14
# PERSON Darwin
# DATE 1871
# WORK_OF_ART The Descent of Man:
# PERSON Byron
# PERSON Howard
# ORG Clarkson
# GPE Newton
# ORG Shakspeare
# PERSON Darwin
# PERSON Isaac Newton
# PERSON William Shakespeare
# PERSON Thomas Clarkson
# PERSON John Howard
# LANGUAGE English
# NORP Christian
# PERSON Darwin
# PERSON Darwin
# DATE the 20th century
# NORP German
# PERSON Ernst Haeckel
# NORP Jews
# NORP Germans
# LANGUAGE English
# CARDINAL 15
# NORP Nazi
# NORP Jews
# NORP Papuans
# DATE 1938
# PERSON Der Giftpilz
# NORP Jew
# NORP Jew
# NORP Jewish
# CARDINAL six
# CARDINAL 7
# ORG Vaught’s
# PERSON Character Reader
# DATE 1902
# CARDINAL 80
# CARDINAL 8
# NORP Nazi
# DATE 1933
# DATE today
# DATE the past half-century
# NORP American
# PERSON James Weidmann
# PERSON Wu
# PERSON Zhang
# NORP Israeli
# ORG Faception
# ORDINAL first
# CARDINAL 16
# PERSON Wu
# PERSON Zhang
# CARDINAL one
# CARDINAL less than one tenth
# ORDINAL second
# PERSON Fundamentally
# ORG Criminality
# ORG Criminal
# NORP ’s
# CARDINAL 17
# PERSON Dorothea Lange
# WORK_OF_ART Migrant Mother
# DATE 1936
# EVENT the Dust Bowl
# NORP American
# DATE 30s
# PERSON Lange
# CARDINAL 9
# PERSON Dorothea Lange
# WORK_OF_ART Migrant Mother
# GPE California
# DATE 32 year old
# CARDINAL seven
# DATE February 1936
# PERSON Lange
# EVENT the Dust Bowl
# CARDINAL two
# CARDINAL one
# DATE 2011
# ORG Cognition
# PERSON Mike Burton
# CARDINAL 10
# LOC R. Jenkins
# DATE 2011
# LOC Variability
# CARDINAL two
# CARDINAL two
# PERSON Canon Lab
# GPE Australia
# CARDINAL five
# TIME a few minutes
# GPE Australia
# DATE 2011
# GPE Valla
# ORG The Accuracy of Inferences About Criminality Based on Facial Appearance
# GPE Lavater, Lombroso
# ORG Galton
# PERSON Stephen Jay Gould
# DATE 1981
# WORK_OF_ART The Mismeasure of Man
# ORG Plato
# DATE 19th century
# GPE England
# NORP Victorian
# PERSON Philippa Fawcett
# ORG Cambridge Mathematical Tripos
# DATE 1890
# CARDINAL 18
# DATE the past century
# ORDINAL first
# DATE the 19th century
# PERSON Robert Hughes
# GPE England
# DATE 80 year
# GPE Australia
# WORK_OF_ART The Fatal Shore
# GPE Australia
# GPE England
# GPE Australia
# CARDINAL 19
# PERSON Dorothea Lange
# LOC Dust Bowl
# DATE 19th century
# GPE England
# PERSON Georg Christoph Lichtenberg
# CARDINAL 20
# GPE testosterone
# PERCENT 53% and
# PERCENT 57%
# GPE Neave
# GPE Laing
# PERSON Manning
# DATE 2003
# ORDINAL second
# ORDINAL fourth
# CARDINAL 2D:4D
# GPE Ferdenzi
# ORG Leongómez
# PERSON Roberts
# DATE 2011
# CARDINAL 2D:4D
# CARDINAL one
# PERSON Wu
# CARDINAL three
# CARDINAL three
# DATE the last several years
# GPE US
# GPE US
# PERCENT about 5%
# PERCENT 25%
# CARDINAL 2.4 million
# GPE US
# CARDINAL nearly seven
# CARDINAL 21
# GPE US
# PERSON Wu
# PERSON Zhang
# GPE China
# GPE US
# GPE England
# DATE the 19th century
# CARDINAL about 5.8
# PERCENT 10%
# CARDINAL 22
# CARDINAL one
# PERSON Wu
# PERSON Zhang
# CARDINAL 23
# CARDINAL 24
# DATE 2015
# PERSON Brian Holtz
# ORG Temple University
# GPE Oosterhof
# ORG Todorov
# DATE 2008
# DATE 4-year olds
# CARDINAL 25
# PERSON Wu
# PERSON Zhang
# DATE the coming years
# NORP Indian
# NORP Indian
# PERSON Sherman Alexie
# PERSON Sherman Alexie
# CARDINAL about one
# PERSON Wu
# PERSON Zhang
# ORG Faception
# PERSON Wu
# PERSON Zhang
# CARDINAL one
# ORG TIME Magazine’s
# CARDINAL 50
# DATE 2011
# GPE US
# PERSON Wu
# PERSON Zhang
# PERSON Wu
# PERSON Zhang
# ORG Faception’s
# PERSON Charina Choi
# ORG Google
# PERSON Jason Friedenfelds
# ORG Google
#
#
# Tobias Weyand
# ORG Google
# PERSON Tim Freeman
# ORG Google
# PERSON Alison Lentz
# PERSON Jac de Haan
# ORG Google
# PERSON Meredith Whittaker
# ORG Google
# PERSON Kathryn Hume
# PERSON Fast Forward Labs
# CARDINAL 1
# CARDINAL 2
# ORDINAL first
# CARDINAL 3
# CARDINAL one
# CARDINAL 4
# ORG ChronoNet
# CARDINAL 5
# CARDINAL 6
# CARDINAL 7
# NORP Dutch
# PERSON Pieter Camper
# CARDINAL 8
# GPE prosopagnosia
# PERSON Chuck Close
# CARDINAL 9
# DATE the past few years
# DATE decades
# CARDINAL 10
# ORDINAL first
# WORK_OF_ART Face Value: The Irresistible Influence of First Impressions
# CARDINAL one
# CARDINAL 11
# NORP Greek
# LANGUAGE English
# CARDINAL 12
# ORDINAL second
# CARDINAL 13
# DATE today
# CARDINAL 14
# PERSON Darwin
# PERSON Darwin
# CARDINAL one
# CARDINAL 15
# NORP Jewish
# GPE Germany
# PERSON Darwin
# NORP Jewish
# NORP English
# CARDINAL 16
# WORK_OF_ART Bingo Player
# ORG Bingo Player
# CARDINAL 17
# CARDINAL 18
# MONEY 13 per cent
# ORDINAL second
# ORG Wikipedia
# CARDINAL 19
# LAW Chapter 10
# CARDINAL 48
# CARDINAL 20
# GPE US
# PERCENT 98%
# PERCENT 90%
# PERCENT 78%
# PERCENT only 57%
# PERCENT 51%
# NORP Canadian
# CARDINAL 21
# ORG Hispanic/Latino
# CARDINAL 22
# CARDINAL 23
# NORP Chinese
# CARDINAL 24
# ORDINAL first
# PERSON Face Value
# ORG The Irresistible Influence of
# CARDINAL 25
# PERSON Malcolm Gladwell
# PERSON Blink
# CARDINAL ﻿édition
# NORP Dans
# WORK_OF_ART Monde
# PERSON Charles Cuvelliez
# PERSON de l’homme
# ORG un
# FAC Le Monde
# ORG Par Charles Cuvelliez
# ORG Professeur
# ORG fondateur
# CARDINAL 3
# GPE IA
# FAC Le quotidien
# ORG affreux de ces modérateurs
# PERSON longueur de journée
# PERSON L’IA
# PERSON nos emplois
# PERSON la convivialité
# ORG un
# PERSON de l’IA qui n’a
# ORG dans la réalité
# PERSON jamais pu être mise
# DATE 1955
# PERSON qu’on leur
# ORG un
# PERSON que toute
# ORG un
# DATE d’une
# PERSON Comme
# ORG un
# GPE Livre
# PERSON l’Intelligence arti­ficielle
# PERSON Julien Maldonato
# ORG Deloitte
# DATE 2017
# ORG un
# ORG dans sa
# PERSON L’IA
# ORG Il s’agit d’un apprentissage sur des
# NORP n’explique
# NORP dans
# ORG un
# PERSON C’est
# PERSON artificielle maîtrisée
# CARDINAL 29
# DATE 2017
# PERSON pour qui
# NORP sans
# PERSON bien comprendre
# ORG Apple
# PERSON Uber
# PERSON Travis Kalanick
# ORG Uber
# PERSON Tim Cook
# ORG Apple
# CARDINAL Millions
# ORG Uber
# LOC Silicon Valley’s
# NORP democratic
# ORG Yahoo
# PERSON Marissa Mayer
# MONEY 186
# '\nGreat work!\n'

# %%
import polyglot
import icu
from polyglot.text import Text

# %%
# exercise 04

"""
French NER with polyglot I

In this exercise and the next, you'll use the polyglot library to identify French entities. The library functions slightly differently than spacy, so you'll use a few of the new things you learned in the last video to display the named entity text and category.

You have access to the full article string in article. Additionally, the Text class of polyglot has been imported from polyglot.text.
"""

# Instructions

"""

    Using the article string in article, create a new Text object called txt.
    Iterate over txt.entities and print each entity, ent.
    Print the type() of ent.

"""

# solution

# Create a new text object using Polyglot's Text class: txt
txt = Text(article)

# Print each of the entities found
for ent in txt.entities:
    print(ent)
    
# Print the type of ent
print(type(ent))


#----------------------------------#

# Conclusion

"""
Great work!
"""
# Out:
# ['Uber']
# ['Uber']
# ['Reuters']
# ['greyball']
# ['Portland', ',', 'Oregon']
# ['Greyball']
# ['Portland']
# ['Uber']
# ['New', 'York', 'Times']
# ['Uber']
# ['Google']
# ['Siri']
# ['Rachael', 'Tatman']
# ['New', 'Zealand']
# ['Tatman']
# ['San', 'Francisco']
# ['”']
# ['Twitter']
# ['”']
# ['University', 'of', 'Washington’s']
# ['Central']
# ['Learning']
# ['Apple’s', 'Siri']
# ['there’s']
# ['“']
# ['”', 'Tatman']
# ['they’ve']
# ['Tatman']
# ['California']
# ['United', 'States']
# ['”']
# ['Stephen', 'Scarr']
# ['Scarr']
# ['Alonso', 'Martinez']
# ['Pixar', 'Animation', 'Studios']
# ['”']
# ['Martinez']
# ['Emeryville']
# ['Elena', 'Corina', 'Grigore']
# ['Yale']
# ['Social', 'Robotics', 'Lab']
# ['That’s']
# ['Grigore']
# ['Ikea']
# ['Grigore']
# ['“', 'We’re']
# ['We’re']
# ['”', 'Benny', 'Evangelista']
# ['San', 'Francisco', 'Chronicle']
# ['Britain']
# ['Germany']
# ['Computer']
# ['Europe']
# ['United']
# ['Facebook']
# ['Twitter']
# ['”']
# ['Claire', 'Wardle']
# ['United', 'States']
# ['Europe']
# ['“']
# ['United']
# ['United', 'States']
# ['Europe']
# ['United', 'States']
# ['United', 'States']
# ['Europe']
# ['Russian']
# ['”']
# ['Janis', 'Sarts']
# ['NATO', 'Strategic', 'Communications', 'Center', 'of', 'Excellence']
# ['Riga']
# ['Latvia']
# ['”']
# ['Facebook']
# ['Google']
# ['Silicon', 'Valley']
# ['The', 'New']
# ['The', 'New', 'York']
# ['New', 'York', 'Times']
# ['States']
# ['Facebook']
# ['France']
# ['Google']
# ['David', 'Dieudonné']
# ['France']
# ['Saudi', 'Arabia']
# ['Emmanuel', 'Macron']
# ['Mr']
# ['Dieudonné']
# ['“']
# ['David', 'Chavalarias']
# ['United', 'States']
# ['Dean', 'Pomerleau']
# ['Carnegie', 'Mellon', 'University']
# ['Pittsburgh']
# ['Twitter']
# ['Delip', 'Rao']
# ['Google']
# ['Pomerleau’s']
# ['Pomerleau']
# ['”']
# ['Pomerleau']
# ['Jimmy', 'Wales']
# ['—']
# ['United']
# ['Wales']
# ['”']
# ['“']
# ['”', 'Ruchir', 'Sharma']
# ['Morgan', 'Stanley', 'Investment', 'Management']
# ['Nations']
# ['Forces']
# ['Singapore']
# ['Edgar', 'Su']
# ['United', 'Nations']
# ['populists']
# ['we’re']
# ['Chile']
# ['China']
# ['United', 'States']
# ['Germany']
# ['Japan']
# ['South', 'Korea']
# ['China']
# ['Evercore', 'ISI']
# ['United', 'States']
# ['France']
# ['China']
# ['Daniel', 'Kahneman']
# ['China']
# ['Beijing']
# ['Oxford', 'University']
# ['Carl', 'Benedikt', 'Frey']
# ['Michael', 'Osborne']
# ['Machine', 'Intelligence', 'Research']
# ['University', 'of', 'California']
# ['Berkeley']
# ['cashiers']
# ['paralegals']
# ['Martin', 'Ford’s']
# ['”']
# ['We’re']
# ['Germany']
# ['Japan']
# ['South', 'Korea']
# ['China']
# ['Nigeria']
# ['Saudi', 'Arabia']
# ['Singapore']
# ['Chile']
# ['Australia']
# ['Japan']
# ['Germany']
# ['Germany']
# ['Germany']
# ['Japan']
# ['United', 'States']
# ['International', 'Federation', 'of', 'Robotics']
# ['South', 'Korea']
# ['Japan']
# ['Germany']
# ['United', 'States']
# ['China']
# ['they’re']
# ['Prof', 'Björn', 'Schuller']
# ['Imperial', 'College', 'London']
# ['”']
# ['Oz']
# ['”']
# ['Schuller']
# ['Minlie', 'Huang']
# ['Tsinghua', 'University']
# ['Beijing']
# ['“']
# ['”', 'Huang']
# ['Weibo']
# ['–']
# ['“']
# ['”']
# ['Huang']
# ['Eugene', 'Goostman']
# ['Tay']
# ['Sandra', 'Wachter']
# ['Oxford', 'Internet', 'Institute']
# ['”']
# ['”']
# ['”']
# ['Schuller']
# ['“']
# ['Ilya', 'Kostrikov']
# ['Tobias', 'Weyand’s', 'ChronoNet']
# ['CNN']
# ['Marco', 'Polo']
# ['Wu']
# ['Wu']
# ['Xi']
# ['Wu']
# ['physiognomy']
# ['Lombroso']
# ['Lombroso']
# ['”']
# ['Cesare', 'Lombroso']
# ['Lombroso']
# ['Italy']
# ['Giuseppe', 'Villella']
# ['—']
# ['Villella']
# ['Pavia']
# ['Italy']
# ['Stockholm']
# ['Nixon']
# ['Atlanta']
# ['Stockholm']
# ['Wu']
# ['”']
# ['Wu']
# ['Zhang']
# ['”']
# ['China']
# ['Guangdong']
# ['Jiangsu']
# ['Liaoning']
# ['China']
# ['Wu']
# ['Zhang']
# ['Alex', 'Krizhevsky']
# ['Ilya', 'Sutskever']
# ['Geoffrey', 'Hinton']
# ['CNN']
# ['Gil', 'Levi']
# ['Tal', 'Hassner']
# ['Wu']
# ['Zhang’s']
# ['”']
# ['CNN']
# ['CNN']
# ['”']
# ['”']
# ['Wu']
# ['Zhang']
# ['Wu']
# ['Zhang’s']
# ['segregating']
# ['Wu']
# ['Zhang']
# ['Wu']
# ['Zhang']
# ['Valla', 'et']
# ['Wu']
# ['Zhang']
# ['Psychological']
# ['“']
# ['Wu']
# ['Zhang’s']
# ['Wu']
# ['Zhang', 'don’t']
# ['Wu']
# ['Zhang']
# ['Cesare', 'Lombroso']
# ['Giambattista', 'della']
# ['della']
# ['Naples']
# ['Swiss']
# ['Johann', 'Caspar', 'Lavater']
# ['”']
# ['Francis', 'Galton']
# ['Lombroso']
# ['Francis', 'Galton’s']
# ['”']
# ['Italy']
# ['physiognomists']
# ['Samuel', 'Morton']
# ['Josiah', 'Nott']
# ['George', 'Gliddon']
# ['“', 'Intelligence']
# ['Caucasian']
# ['Nott']
# ['Gliddon']
# ['Darwin']
# ['Byron']
# ['Howard']
# ['Clarkson']
# ['Isaac', 'Newton']
# ['William', 'Shakespeare']
# ['Thomas', 'Clarkson']
# ['John', 'Howard']
# ['Darwin']
# ['Ernst', 'Haeckel']
# ['Nazi']
# ['Haeckel']
# ['Papuans']
# ['Hottentots']
# ['Der']
# ['Nazi']
# ['”']
# ['James', 'Weidmann']
# ['Wu']
# ['Israeli']
# ['“']
# ['”']
# ['Wu']
# ['Zhang']
# ['”']
# ['Dorothea', 'Lange’s']
# ['Dorothea', 'Lange’s', '“']
# ['peapickers']
# ['California']
# ['Dust']
# ['Research']
# ['Mike', 'Burton']
# ['Jenkins']
# ['Canon', 'Lab', 'Australia']
# ['”']
# ['”']
# ['Canon', 'Lab']
# ['Valla', 'et']
# ['Galton', '—']
# ['Essentialism']
# ['Stephen', 'Jay', 'Gould']
# ['Plato']
# ['England']
# ['Philippa', 'Fawcett']
# ['Cambridge']
# ['”']
# ['Robert', 'Hughes', 'colorfully']
# ['Australia']
# ['Australia']
# ['England']
# ['Australia']
# ['Dorothea', 'Lange’s']
# ['England']
# ['”']
# ['Georg', 'Christoph', 'Lichtenberg']
# ['Neave']
# ['Laing']
# ['Fink']
# ['Manning']
# ['Roberts']
# ['Wu']
# ['”']
# ['Wu']
# ['Zhang']
# ['China']
# ['Wu']
# ['Zhang']
# ['Brian', 'Holtz']
# ['Temple', 'University']
# ['”']
# ['Wu']
# ['you’re']
# ['”', '—', 'Sherman', 'Alexie']
# ['Sherman']
# ['Wu']
# ['Wu']
# ['Zhang']
# ['”']
# ['Wu']
# ['Wu']
# ['Charina', 'Choi']
# ['Jason', 'Friedenfelds']
# ['Tobias', 'Weyand']
# ['Google']
# ['Google', 'Tim', 'Freeman']
# ['Alison', 'Lentz']
# ['Jac', 'de', 'Haan']
# ['Meredith', 'Whittaker']
# ['Kathryn', 'Hume']
# ['Labs']
# ['—']
# ['Pieter', 'Camper']
# ['Chuck', 'Close']
# ['”']
# ['Man', 'Darwin']
# ['Haeckel']
# ['Darwin']
# ['Malcolm', 'Gladwell’s']
# ['\ufeff']
# ['l’universitaire', 'Charles', 'Cuvelliez', 'estime']
# ['Charles', 'Cuvelliez']
# ["l'université"]
# ['Bruxelles']
# ['TRIBUNE']
# ['L’usage']
# ['Facebook']
# ['fondateur', 'à']
# ['supplémentaires']
# ['quotidien']
# ['contraints']
# ['accusée']
# ['arti\xadficielle']
# ['Julien', 'Maldonato']
# ['Deloitte']
# ['c’est']
# ['explique', 'l’auteur']
# ['artificielle']
# ['Uber']
# ['Uber']
# ['notionally']
# ['Uber']
# ['Uber']
# ['Travis', 'Kalanick']
# ['Uber']
# ['Tim', 'Cook']
# ['Apple']
# ['Yahoo']
# ['Marissa', 'Mayer']
# <class 'polyglot.text.Chunk'>
# '\nGreat work!\n'

# %%
# exercise 05

"""
French NER with polyglot II

Here, you'll complete the work you began in the previous exercise.

Your task is to use a list comprehension to create a list of tuples, in which the first element is the entity tag, and the second element is the full string of the entity text.
"""

# Instructions

"""

    Use a list comprehension to create a list of tuples called entities.
    The output expression of your list comprehension should be a tuple.
        The first element of each tuple is the entity tag, which you can access using its .tag attribute.
        The second element is the full string of the entity text, which you can access using .join(ent).
    Your iterator variable should be ent, and you should iterate over all of the entities of the polyglot Text object, txt.
    Print entities to see what you've created.

"""

# solution

# Create the list of tuples: entities
entities = [(ent.tag, ' '.join(ent)) for ent in txt.entities]

# Print entities
print(entities)


#----------------------------------#

# Conclusion

"""
Great work! Let's see how polyglot can handle Spanish now!
"""
# Out:
# [('I-PER', 'Uber'), ('I-PER', 'Uber'), ('I-ORG', 'Reuters'), ('I-PER', 'greyball'), ('I-LOC', 'Portland , Oregon'), ('I-PER', 'Greyball'), ('I-LOC', 'Portland'), ('I-PER', 'Uber'), ('I-ORG', 'New York Times'), ('I-PER', 'Uber'), ('I-ORG', 'Google'), ('I-PER', 'Siri'), ('I-PER', 'Rachael Tatman'), ('I-LOC', 'New Zealand'), ('I-PER', 'Tatman'), ('I-LOC', 'San Francisco'), ('I-PER', '”'), ('I-ORG', 'Twitter'), ('I-PER', '”'), ('I-ORG', 'University of Washington’s'), ('I-ORG', 'Central'), ('I-ORG', 'Learning'), ('I-PER', 'Apple’s Siri'), ('I-PER', 'there’s'), ('I-LOC', '“'), ('I-PER', '” Tatman'), ('I-PER', 'they’ve'), ('I-PER', 'Tatman'), ('I-LOC', 'California'), ('I-LOC', 'United States'), ('I-PER', '”'), ('I-PER', 'Stephen Scarr'), ('I-PER', 'Scarr'), ('I-PER', 'Alonso Martinez'), ('I-ORG', 'Pixar Animation Studios'), ('I-PER', '”'), ('I-PER', 'Martinez'), ('I-ORG', 'Emeryville'), ('I-PER', 'Elena Corina Grigore'), ('I-ORG', 'Yale'), ('I-ORG', 'Social Robotics Lab'), ('I-PER', 'That’s'), ('I-PER', 'Grigore'), ('I-ORG', 'Ikea'), ('I-PER', 'Grigore'), ('I-PER', '“ We’re'), ('I-PER', 'We’re'), ('I-PER', '” Benny Evangelista'), ('I-ORG', 'San Francisco Chronicle'), ('I-LOC', 'Britain'), ('I-LOC', 'Germany'), ('I-ORG', 'Computer'), ('I-LOC', 'Europe'), ('I-ORG', 'United'), ('I-ORG', 'Facebook'), ('I-ORG', 'Twitter'), ('I-PER', '”'), ('I-PER', 'Claire Wardle'), ('I-LOC', 'United States'), ('I-LOC', 'Europe'), ('I-PER', '“'), ('I-ORG', 'United'), ('I-LOC', 'United States'), ('I-LOC', 'Europe'), ('I-LOC', 'United States'), ('I-LOC', 'United States'), ('I-LOC', 'Europe'), ('I-LOC', 'Russian'), ('I-PER', '”'), ('I-PER', 'Janis Sarts'), ('I-ORG', 'NATO Strategic Communications Center of Excellence'), ('I-LOC', 'Riga'), ('I-LOC', 'Latvia'), ('I-PER', '”'), ('I-ORG', 'Facebook'), ('I-ORG', 'Google'), ('I-LOC', 'Silicon Valley'), ('I-ORG', 'The New'), ('I-LOC', 'The New York'), ('I-ORG', 'New York Times'), ('I-LOC', 'States'), ('I-ORG', 'Facebook'), ('I-LOC', 'France'), ('I-ORG', 'Google'), ('I-PER', 'David Dieudonné'), ('I-LOC', 'France'), ('I-LOC', 'Saudi Arabia'), ('I-PER', 'Emmanuel Macron'), ('I-PER', 'Mr'), ('I-PER', 'Dieudonné'), ('I-PER', '“'), ('I-PER', 'David Chavalarias'), ('I-LOC', 'United States'), ('I-PER', 'Dean Pomerleau'), ('I-ORG', 'Carnegie Mellon University'), ('I-LOC', 'Pittsburgh'), ('I-ORG', 'Twitter'), ('I-PER', 'Delip Rao'), ('I-ORG', 'Google'), ('I-PER', 'Pomerleau’s'), ('I-PER', 'Pomerleau'), ('I-PER', '”'), ('I-PER', 'Pomerleau'), ('I-PER', 'Jimmy Wales'), ('I-PER', '—'), ('I-ORG', 'United'), ('I-PER', 'Wales'), ('I-PER', '”'), ('I-PER', '“'), ('I-PER', '” Ruchir Sharma'), ('I-ORG', 'Morgan Stanley Investment Management'), ('I-ORG', 'Nations'), ('I-ORG', 'Forces'), ('I-LOC', 'Singapore'), ('I-PER', 'Edgar Su'), ('I-ORG', 'United Nations'), ('I-PER', 'populists'), ('I-PER', 'we’re'), ('I-LOC', 'Chile'), ('I-LOC', 'China'), ('I-LOC', 'United States'), ('I-LOC', 'Germany'), ('I-LOC', 'Japan'), ('I-LOC', 'South Korea'), ('I-LOC', 'China'), ('I-ORG', 'Evercore ISI'), ('I-LOC', 'United States'), ('I-LOC', 'France'), ('I-LOC', 'China'), ('I-PER', 'Daniel Kahneman'), ('I-LOC', 'China'), ('I-LOC', 'Beijing'), ('I-ORG', 'Oxford University'), ('I-PER', 'Carl Benedikt Frey'), ('I-PER', 'Michael Osborne'), ('I-ORG', 'Machine Intelligence Research'), ('I-ORG', 'University of California'), ('I-LOC', 'Berkeley'), ('I-PER', 'cashiers'), ('I-LOC', 'paralegals'), ('I-PER', 'Martin Ford’s'), ('I-PER', '”'), ('I-PER', 'We’re'), ('I-LOC', 'Germany'), ('I-LOC', 'Japan'), ('I-LOC', 'South Korea'), ('I-LOC', 'China'), ('I-LOC', 'Nigeria'), ('I-LOC', 'Saudi Arabia'), ('I-LOC', 'Singapore'), ('I-LOC', 'Chile'), ('I-LOC', 'Australia'), ('I-LOC', 'Japan'), ('I-LOC', 'Germany'), ('I-LOC', 'Germany'), ('I-LOC', 'Germany'), ('I-LOC', 'Japan'), ('I-LOC', 'United States'), ('I-ORG', 'International Federation of Robotics'), ('I-LOC', 'South Korea'), ('I-LOC', 'Japan'), ('I-LOC', 'Germany'), ('I-ORG', 'United States'), ('I-LOC', 'China'), ('I-PER',  ...
# "\nGreat work! Let's see how polyglot can handle Spanish now!\n"

# %%
text = """Lina del Castillo es profesora en el Instituto de Estudios Latinoamericanos Teresa Lozano Long (LLILAS) y el Departamento de Historia de la Universidad de Texas en Austin. Ella será la moderadora del panel “Los Mundos Políticos de Gabriel García Márquez” este viernes, Oct. 30, en el simposio Gabriel García Márquez: Vida y Legado.


LIna del Castillo


Actualmente, sus investigaciones abarcan la intersección de cartografía, disputas a las demandas de tierra y recursos, y la formación del n...el tren de medianoche que lleva a miles y miles de cadáveres uno encima del otro como tantos racimos del banano que acabarán tirados al mar. Ningún recuento periodístico podría provocar nuestra imaginación y nuestra memoria como este relato de García Márquez.


Contenido Relacionado


Lea más artículos sobre el archivo de Gabriel García Márquez


Reciba mensualmente las últimas noticias e información del Harry Ransom Center con eNews, nuestro correo electrónico mensual. ¡Suscríbase hoy!"""

# %%
txt = Text(text)

# %%
# exercise 06

"""
Spanish NER with polyglot

You'll continue your exploration of polyglot now with some Spanish annotation. This article is not written by a newspaper, so it is your first example of a more blog-like text. How do you think that might compare when finding entities?

The Text object has been created as txt, and each entity has been printed, as you can see in the IPython Shell.

Your specific task is to determine how many of the entities contain the words "Márquez" or "Gabo" - these refer to the same person in different ways!
"""

# Instructions

"""

    Iterate over all of the entities of txt, using ent as your iterator variable.
    Check whether the entity contains "Márquez" or "Gabo". If it does, increment count. Don't forget to include the accented á in "Márquez"!
    Hit 'Submit Answer' to see what percentage of entities refer to Gabriel García Márquez (aka Gabo).

"""

# solution

# Initialize the count variable: count
count = 0

# Iterate over all the entities
for ent in txt.entities:
    # Check whether the entity contains 'Márquez' or 'Gabo'
    if "Márquez" in ent or 'Gabo' in ent:
        # Increment count
        count += 1

# Print count
print(count)

# Calculate the percentage of entities that refer to "Gabo": percentage
percentage = count / len(txt.entities)
print(percentage)


#----------------------------------#

# Conclusion

"""
Great work!
"""
# Out:
# 4
# 0.26666666666666666
# '\nGreat work!\n'
